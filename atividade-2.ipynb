# %% [markdown]
# ### 1 $)$ Gradiente Descendente

# %% [markdown]
# #### 1.1 $)$ Explicação de Conceitos Base anteriores a Descida do Gradiente

# %% [markdown]
# Antes de explicar propriamente Gradiente Descendente é necessário explicar alguns termos que serão abordados enquanto usa-se Gradiente Descendente.

# %% [markdown]
# ##### 1.1.1 $)$ Função Linear

# %% [markdown]
# O exemplo abordado nesta atividade faz uso das variaveis peso e altura, trata-se de uma função afim de forma genérica:

# %% [markdown]
# $f(x) = ax + b$
#
# Com $a$ sendo o coeficiente angular(slope), ele determina se a reta será crescente($a> 0$) ou decrescente($a< 0$).
#
# $b$ trata-se do coeficiente linear(intercept), basicamente é onde a reta da função $f(x)$ vai cruzar no eixo das ordenadas de $Y$.

# %% [markdown]
# No exemplo, a função dada é da Altura Prevista(Predicted Height), que basicamente é uma função linear para prever alturas baseado em pesos(a unidade de peso não tem tanta importância).
#
# A função é da seguinte forma:

# %% [markdown]
# $Predicted Height = slope \cdot height + Intercept$

# %% [markdown]
# ##### 1.1.2) Chute Inicial(Initial Guess)

# %% [markdown]
# O Initial Guess dá valores iniciais para os parâmetros do Gradiente Descendente antes das iterações. No caso do exemplo, os seguintes valores:

# %% [markdown]
# \begin{align*}
# slope = 0.64 \quad
# intercept = 0
# \end{align*}

# %% [markdown]
# Posteriormente esses valores serão usados. Não há uma forma correta para se dar um Chute Inicial, mas há formas que geram resultados mais positivos do que outras, como escolher valores pequenos ou iguais a 0. Um Initial Guess bem feito pode reduzir o número de iterações que o Gradiente Descendente teria de fazer.

# %% [markdown]
# ##### 1.1.3 $)$ Função de Perda(Loss Function)

# %% [markdown]
# uma função de perda é usada para medir o desempenho de um modelo, calculando o desvio das previsões de um modelo em relação às previsões corretas de uma base de dados. No exemplo que será seguido a Loss Function usada será a de Soma dos Quadrados dos Resíduos(Sum of the Squared Residuals). Também pode ser chamado de SSR.
#
# A função consiste na soma dos quadrados das diferenças entre os valores reais da variável dependente e os valores previstos pelo modelo. As funções de perda são específicas do aprendizado supervisionado, em que as tarefas de treinamento pressupõem a existência de uma resposta correta, uma "verdade absoluta".

# %% [markdown]
# O resíduo ao quadrado é obtido da seguinte forma:
#
# $Residual = (Observerd Height - Predicted Height)$ <sup>2<sup>
#
# E por tratar-se de uma soma, ela fica num somatório:
#
# $\sum_{i=1}^{n} Residual$

# %% [markdown]
# ##### 1.1.4 $)$ Regra da Cadeia(Chain Rule)

# %% [markdown]
# A Regra da Cadeia será aplicada na Função de Perda(Loss Function) citada anteriormente a fim de determinar o Coeficiente Angular(slop) por meio de qualquer valor do Coeficiente Linear(intercept).
#
# A Regra da Cadeia é da seguinte forma:

# %% [markdown]
# $$
# \frac{d}{dx} f(g(x)) = f'(g(x)) \cdot g'(x)
# $$

# %% [markdown]
# E derivando a Função de Perda é encontra-se a inclinação da reta tangente a uma curva, para a função usada ela fica no seguinte formato:

# %% [markdown]
# $$
# \frac{d}{dx} SumSquaredResiduals = -2 \cdot ( ObservedHeitght - (Intercept + 0.64 \cdot Weitght))
# $$

# %% [markdown]
# #### 1.1.5 $)$ Passos, Taxa de Aprendizado e Novo Coeficiente Linear(New Concept)

# %% [markdown]
# A Descida do Gradiente dita o tamanho dos passos dados, ocorre da seguinte forma:
#
# $StepSize = Slope \cdot LearningRate$
#
# O tamanho dos passos está relacioando com o Coeficiente Angular, quanto mais perto do valor ótimo, mais perto de 0 o Slope da Curva(obtida pela derivada) chega de 0. Então quanto mais próximo de 0, o valor dos passos tem de ser menor. Quanto mais longe de 0 estiver, maiores os passos podem ser, no entanto
#
# O $Slope$ mencionado é da Derivada do algoritmo SSR.

# %% [markdown]
# O Novo Coeficiente Linear é obtido subtraindo o Tamanho do Passo(Step Size) do Old Intercept(Antigo Coeficiente Linear), na seguinte forma:
#
# $New Intercept = Old Intercept - StepSize$

# %% [markdown]
# Esse Novo Intercept será usado na próxima iteração do Gradiente Descendente como o intercept.

# %% [markdown]
# #### 1.2 $)$ Explicação de Gradiente Descendente

# %% [markdown]
# A descida do Gradiente tem o objetivo de obter o valor mínimo da Função de Perda, isto é, o menor valor da Soma Residual ao Quadrado. Isso significa que quanto menor for a Perda(função) mais otimizado o modelo fica, mas para encontrar esse valor seriam necessários vários testes com valores de $intercept$ diferentes, o que não é nada eficiente.
#
# O algoritmo de Descida de Gradiente entra em jogo para tornar esse processo mais eficiente. O algoritmo inicia-se longe do valor ideal, fazendo poucos cálculos, e quanto mais perto de um valor mínimo, mais cálculos são executados. Basicamente, passos largos e passos pequenos.

# %%
#Valores
weight = [0.5, 2.3, 2.9]
height_O = [1.4, 1.9, 3.2]

lr = 0.1
residual = 0
max_steps = 100
m_step_size = 0.001

#Funções

def predict(h, intercept, slope):
	return intercept + slope * h

def d_ssr(height_O, weight, intercept, slope):
	slope = 0
	for i in range (len(weight)):
		slope += -2*(height_O[i]-predict(weight[i], intercept, slope))
	return slope
	
def step_size(slope, lr):
	step_s = slope * lr
	return step_s

def new_intercept(stepS, old_intercept):
	n_i = old_intercept - stepS
	return n_i

def Gradient_Descent(max_steps, m_steps_size, lr):
	slope = 0.64
	intercept = 0
	
	for i in range(max_steps):

		n_slope = d_ssr(height_O, weight, intercept, slope)

		step = step_size(n_slope, lr)

		n_intercept = new_intercept(step, intercept)
		print(f"Passo {i+1}: coeficiente angular = {n_slope:.2}, novo intercepto = {n_intercept:.2}, tamanho do passo = {step:.2}")
		
		intercept = n_intercept
		if abs(step) < m_steps_size:
			print(f"o menor coeficiente angular já foi obtido: {n_slope}")
			break
	return intercept

Gradient_Descent(max_steps, m_step_size, lr)
# Out:
# Passo 1: coeficiente angular = -1.4e+02, novo intercepto = 1.4e+01, tamanho do passo = -1.4e+01
# Passo 2: coeficiente angular = 1.1e+03, novo intercepto = -1e+02, tamanho do passo = 1.1e+02
# Passo 3: coeficiente angular = -9.3e+03, novo intercepto = 8.3e+02, tamanho do passo = -9.3e+02
# Passo 4: coeficiente angular = 7.6e+04, novo intercepto = -6.8e+03, tamanho do passo = 7.6e+03
# Passo 5: coeficiente angular = -6.2e+05, novo intercepto = 5.5e+04, tamanho do passo = -6.2e+04
# Passo 6: coeficiente angular = 5.1e+06, novo intercepto = -4.5e+05, tamanho do passo = 5.1e+05
# Passo 7: coeficiente angular = -4.1e+07, novo intercepto = 3.7e+06, tamanho do passo = -4.1e+06
# Passo 8: coeficiente angular = 3.4e+08, novo intercepto = -3e+07, tamanho do passo = 3.4e+07
# Passo 9: coeficiente angular = -2.8e+09, novo intercepto = 2.5e+08, tamanho do passo = -2.8e+08
# Passo 10: coeficiente angular = 2.3e+10, novo intercepto = -2e+09, tamanho do passo = 2.3e+09
# Passo 11: coeficiente angular = -1.9e+11, novo intercepto = 1.7e+10, tamanho do passo = -1.9e+10
# Passo 12: coeficiente angular = 1.5e+12, novo intercepto = -1.4e+11, tamanho do passo = 1.5e+11
# Passo 13: coeficiente angular = -1.2e+13, novo intercepto = 1.1e+12, tamanho do passo = -1.2e+12
# Passo 14: coeficiente angular = 1e+14, novo intercepto = -9e+12, tamanho do passo = 1e+13
# Passo 15: coeficiente angular = -8.3e+14, novo intercepto = 7.4e+13, tamanho do passo = -8.3e+13
# Passo 16: coeficiente angular = 6.8e+15, novo intercepto = -6e+14, tamanho do passo = 6.8e+14
# Passo 17: coeficiente angular = -5.5e+16, novo intercepto = 4.9e+15, tamanho do passo = -5.5e+15
# Passo 18: coeficiente angular = 4.5e+17, novo intercepto = -4e+16, tamanho do passo = 4.5e+16
# Passo 19: coeficiente angular = -3.7e+18, novo intercepto = 3.3e+17, tamanho do passo = -3.7e+17
# Passo 20: coeficiente angular = 3e+19, novo intercepto = -2.7e+18, tamanho do passo = 3e+18
# Passo 21: coeficiente angular = -2.5e+20, novo intercepto = 2.2e+19, tamanho do passo = -2.5e+19
# Passo 22: coeficiente angular = 2e+21, novo intercepto = -1.8e+20, tamanho do passo = 2e+20
# Passo 23: coeficiente angular = -1.7e+22, novo intercepto = 1.5e+21, tamanho do passo = -1.7e+21
# Passo 24: coeficiente angular = 1.4e+23, novo intercepto = -1.2e+22, tamanho do passo = 1.4e+22
# Passo 25: coeficiente angular = -1.1e+24, novo intercepto = 9.9e+22, tamanho do passo = -1.1e+23
# Passo 26: coeficiente angular = 9e+24, novo intercepto = -8.1e+23, tamanho do passo = 9e+23
# Passo 27: coeficiente angular = -7.4e+25, novo intercepto = 6.6e+24, tamanho do passo = -7.4e+24
# Passo 28: coeficiente angular = 6e+26, novo intercepto = -5.4e+25, tamanho do passo = 6e+25
# Passo 29: coeficiente angular = -4.9e+27, novo intercepto = 4.4e+26, tamanho do passo = -4.9e+26
# Passo 30: coeficiente angular = 4e+28, novo intercepto = -3.6e+27, tamanho do passo = 4e+27
# Passo 31: coeficiente angular = -3.3e+29, novo intercepto = 2.9e+28, tamanho do passo = -3.3e+28
# Passo 32: coeficiente angular = 2.7e+30, novo intercepto = -2.4e+29, tamanho do passo = 2.7e+29
# Passo 33: coeficiente angular = -2.2e+31, novo intercepto = 2e+30, tamanho do passo = -2.2e+30
# Passo 34: coeficiente angular = 1.8e+32, novo intercepto = -1.6e+31, tamanho do passo = 1.8e+31
# Passo 35: coeficiente angular = -1.5e+33, novo intercepto = 1.3e+32, tamanho do passo = -1.5e+32
# Passo 36: coeficiente angular = 1.2e+34, novo intercepto = -1.1e+33, tamanho do passo = 1.2e+33
# Passo 37: coeficiente angular = -9.9e+34, novo intercepto = 8.8e+33, tamanho do passo = -9.9e+33
# Passo 38: coeficiente angular = 8.1e+35, novo intercepto = -7.2e+34, tamanho do passo = 8.1e+34
# Passo 39: coeficiente angular = -6.6e+36, novo intercepto = 5.9e+35, tamanho do passo = -6.6e+35
# Passo 40: coeficiente angular = 5.4e+37, novo intercepto = -4.8e+36, tamanho do passo = 5.4e+36
# Passo 41: coeficiente angular = -4.4e+38, novo intercepto = 3.9e+37, tamanho do passo = -4.4e+37
# Passo 42: coeficiente angular = 3.6e+39, novo intercepto = -3.2e+38, tamanho do passo = 3.6e+38
# Passo 43: coeficiente angular = -2.9e+40, novo intercepto = 2.6e+39, tamanho do passo = -2.9e+39
# Passo 44: coeficiente angular = 2.4e+41, novo intercepto = -2.1e+40, tamanho do passo = 2.4e+40
# Passo 45: coeficiente angular = -2e+42, novo intercepto = 1.8e+41, tamanho do passo = -2e+41
# Passo 46: coeficiente angular = 1.6e+43, novo intercepto = -1.4e+42, tamanho do passo = 1.6e+42
# Passo 47: coeficiente angular = -1.3e+44, novo intercepto = 1.2e+43, tamanho do passo = -1.3e+43
# Passo 48: coeficiente angular = 1.1e+45, novo intercepto = -9.6e+43, tamanho do passo = 1.1e+44
# Passo 49: coeficiente angular = -8.8e+45, novo intercepto = 7.8e+44, tamanho do passo = -8.8e+44
# Passo 50: coeficiente angular = 7.2e+46, novo intercepto = -6.4e+45, tamanho do passo = 7.2e+45
# Passo 51: coeficiente angular = -5.9e+47, novo intercepto = 5.2e+46, tamanho do passo = -5.9e+46
# Passo 52: coeficiente angular = 4.8e+48, novo intercepto = -4.3e+47, tamanho do passo = 4.8e+47
# Passo 53: coeficiente angular = -3.9e+49, novo intercepto = 3.5e+48, tamanho do passo = -3.9e+48
# Passo 54: coeficiente angular = 3.2e+50, novo intercepto = -2.9e+49, tamanho do passo = 3.2e+49
# Passo 55: coeficiente angular = -2.6e+51, novo intercepto = 2.3e+50, tamanho do passo = -2.6e+50
# Passo 56: coeficiente angular = 2.1e+52, novo intercepto = -1.9e+51, tamanho do passo = 2.1e+51
# Passo 57: coeficiente angular = -1.8e+53, novo intercepto = 1.6e+52, tamanho do passo = -1.8e+52
# Passo 58: coeficiente angular = 1.4e+54, novo intercepto = -1.3e+53, tamanho do passo = 1.4e+53
# Passo 59: coeficiente angular = -1.2e+55, novo intercepto = 1e+54, tamanho do passo = -1.2e+54
# Passo 60: coeficiente angular = 9.6e+55, novo intercepto = -8.6e+54, tamanho do passo = 9.6e+54
# Passo 61: coeficiente angular = -7.9e+56, novo intercepto = 7e+55, tamanho do passo = -7.9e+55
# Passo 62: coeficiente angular = 6.4e+57, novo intercepto = -5.7e+56, tamanho do passo = 6.4e+56
# Passo 63: coeficiente angular = -5.2e+58, novo intercepto = 4.7e+57, tamanho do passo = -5.2e+57
# Passo 64: coeficiente angular = 4.3e+59, novo intercepto = -3.8e+58, tamanho do passo = 4.3e+58
# Passo 65: coeficiente angular = -3.5e+60, novo intercepto = 3.1e+59, tamanho do passo = -3.5e+59
# Passo 66: coeficiente angular = 2.9e+61, novo intercepto = -2.6e+60, tamanho do passo = 2.9e+60
# Passo 67: coeficiente angular = -2.3e+62, novo intercepto = 2.1e+61, tamanho do passo = -2.3e+61
# Passo 68: coeficiente angular = 1.9e+63, novo intercepto = -1.7e+62, tamanho do passo = 1.9e+62
# Passo 69: coeficiente angular = -1.6e+64, novo intercepto = 1.4e+63, tamanho do passo = -1.6e+63
# Passo 70: coeficiente angular = 1.3e+65, novo intercepto = -1.1e+64, tamanho do passo = 1.3e+64
# Passo 71: coeficiente angular = -1e+66, novo intercepto = 9.3e+64, tamanho do passo = -1e+65
# Passo 72: coeficiente angular = 8.6e+66, novo intercepto = -7.6e+65, tamanho do passo = 8.6e+65
# Passo 73: coeficiente angular = -7e+67, novo intercepto = 6.2e+66, tamanho do passo = -7e+66
# Passo 74: coeficiente angular = 5.7e+68, novo intercepto = -5.1e+67, tamanho do passo = 5.7e+67
# Passo 75: coeficiente angular = -4.7e+69, novo intercepto = 4.2e+68, tamanho do passo = -4.7e+68
# Passo 76: coeficiente angular = 3.8e+70, novo intercepto = -3.4e+69, tamanho do passo = 3.8e+69
# Passo 77: coeficiente angular = -3.1e+71, novo intercepto = 2.8e+70, tamanho do passo = -3.1e+70
# Passo 78: coeficiente angular = 2.6e+72, novo intercepto = -2.3e+71, tamanho do passo = 2.6e+71
# Passo 79: coeficiente angular = -2.1e+73, novo intercepto = 1.9e+72, tamanho do passo = -2.1e+72
# Passo 80: coeficiente angular = 1.7e+74, novo intercepto = -1.5e+73, tamanho do passo = 1.7e+73
# Passo 81: coeficiente angular = -1.4e+75, novo intercepto = 1.2e+74, tamanho do passo = -1.4e+74
# Passo 82: coeficiente angular = 1.1e+76, novo intercepto = -1e+75, tamanho do passo = 1.1e+75
# Passo 83: coeficiente angular = -9.4e+76, novo intercepto = 8.3e+75, tamanho do passo = -9.4e+75
# Passo 84: coeficiente angular = 7.6e+77, novo intercepto = -6.8e+76, tamanho do passo = 7.6e+76
# Passo 85: coeficiente angular = -6.3e+78, novo intercepto = 5.6e+77, tamanho do passo = -6.3e+77
# Passo 86: coeficiente angular = 5.1e+79, novo intercepto = -4.6e+78, tamanho do passo = 5.1e+78
# Passo 87: coeficiente angular = -4.2e+80, novo intercepto = 3.7e+79, tamanho do passo = -4.2e+79
# Passo 88: coeficiente angular = 3.4e+81, novo intercepto = -3e+80, tamanho do passo = 3.4e+80
# Passo 89: coeficiente angular = -2.8e+82, novo intercepto = 2.5e+81, tamanho do passo = -2.8e+81
# Passo 90: coeficiente angular = 2.3e+83, novo intercepto = -2e+82, tamanho do passo = 2.3e+82
# Passo 91: coeficiente angular = -1.9e+84, novo intercepto = 1.7e+83, tamanho do passo = -1.9e+83
# Passo 92: coeficiente angular = 1.5e+85, novo intercepto = -1.4e+84, tamanho do passo = 1.5e+84
# Passo 93: coeficiente angular = -1.2e+86, novo intercepto = 1.1e+85, tamanho do passo = -1.2e+85
# Passo 94: coeficiente angular = 1e+87, novo intercepto = -9.1e+85, tamanho do passo = 1e+86
# Passo 95: coeficiente angular = -8.3e+87, novo intercepto = 7.4e+86, tamanho do passo = -8.3e+86
# Passo 96: coeficiente angular = 6.8e+88, novo intercepto = -6.1e+87, tamanho do passo = 6.8e+87
# Passo 97: coeficiente angular = -5.6e+89, novo intercepto = 5e+88, tamanho do passo = -5.6e+88
# Passo 98: coeficiente angular = 4.6e+90, novo intercepto = -4.1e+89, tamanho do passo = 4.6e+89
# Passo 99: coeficiente angular = -3.7e+91, novo intercepto = 3.3e+90, tamanho do passo = -3.7e+90
# Passo 100: coeficiente angular = 3e+92, novo intercepto = -2.7e+91, tamanho do passo = 3e+91
# -2.7165927992570675e+91
